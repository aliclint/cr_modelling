# %%
import pandas as pd
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt 
# %matplotlib inline

pd.set_option('display.max_columns', None)  # allows displaying all columns in a dataframe 
pd.set_option('display.max_rows', 50)
from sklearn.model_selection import train_test_split
from models.classifier import *
from features.build_features import *
from models.model_fit import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-46b8756df8c7> in <module>
#      11 from models.classifier import *
#      12 from features.build_features import *
# ---> 13 from features.model_fit import *
#
# ModuleNotFoundError: No module named 'features.model_fit'

# %%
file_path = 'data//cs-training.csv'
X_train, X_test, y_train, y_test = read_split_data(file_path)
X_train_fs, X_test_fs = feature_processing(X_train, X_test, y_train)
# Out:
# C:\Users\alicl\WCD MLE\credit_risk_modeling\features\build_features.py:62: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf = clf.fit(X_train, y)

# %%
y_pred_base, clf_base = fit_rf(X_train_fs, X_test_fs, y_train.values.ravel())
y_pred_cv, clf_cv = fit_rf_gs_cv(X_train_fs, X_test_fs, y_train.values.ravel())

# %%
generate_classification_report(y_test, y_pred_base)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     27898
#            1       0.00      0.00      0.00      2102
#
#     accuracy                           0.93     30000
#    macro avg       0.46      0.50      0.48     30000
# weighted avg       0.86      0.93      0.90     30000
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
generate_classification_report(y_test, y_pred_cv)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     27898
#            1       0.70      0.07      0.12      2102
#
#     accuracy                           0.93     30000
#    macro avg       0.82      0.53      0.54     30000
# weighted avg       0.92      0.93      0.91     30000

# %% [markdown]
# As expected the gridsearch CV on 5 folds outperform the regular base one.

# %% [markdown]
# ### EDA

# %%
plt.figure()
n, bins, patches = plt.hist(y_train, bins=[-0.5,0.5,1.5],density=True)
plt.xticks([0,1])
plt.xlim([-1, 2])
plt.title('SeriousDlqin2yrs Distribution')
plt.show()

# %%
target_columns = X_train.columns
for i, col in enumerate(target_columns):
    plt.figure(i)
    sns.distplot(X_train[[col]])
    plt.title(col)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i, col in enumerate(target_columns):
  plt.figure(i)
  plt.boxplot(X_train[[col]].values)
  plt.title(col)
plt.show()

# %% [markdown]
# For age it seems to be 20 years old is a good breakpoint from the outlier. On a side note for the upper end - in stochastic mortality modelling there is a breakpoint at the upper end like 80+. Since we are using IQR we and later scaling the data then the cuts shouldn't really matter.

# %%
X_train.describe()
# Out:
#        RevolvingUtilizationOfUnsecuredLines            age  \
# count                         120000.000000  120000.000000
# mean                               5.621098      52.328292
# std                              210.379305      14.782421
# min                                0.000000       0.000000
# 25%                                0.029573      41.000000
# 50%                                0.153917      52.000000
# 75%                                0.558952      63.000000
# max                            29110.000000     109.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120000.000000  120000.000000   9.614200e+04
# mean                               0.428133     352.041463   6.676701e+03
# std                                4.275222    2009.093016   1.555632e+04
# min                                0.000000       0.000000   0.000000e+00
# ...

# %%
correlation_heatmap(X_train)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Automated run from run_save_model() and load the model from file

# %%
run_save_model()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0e30b98c295e> in <module>
# ----> 1 run_save_model()
#
# NameError: name 'run_save_model' is not defined

# %%
filename = 'rf_cv_model.sav'
loaded_model = pickle.load(open(filename, 'rb'))
